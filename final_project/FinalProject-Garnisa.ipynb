# %% [markdown]
# ## TOMO STOCKS

# %%
import datetime
from nltk.chat.util import Chat,reflections

#menu utama
def menu():
    #tanggal
    waktu = datetime.datetime.now()
    print(waktu.strftime("%c"))
    print("")
    print("Halo, saya Tomo Stocks, teman virtualmu seputar saham!\n\n")
    print("---Menu---")
    print("")
    print("1. Kalkulator Deviden")
    print("2. Buat Catatan Sahammu")
    print("3. Ngobrol dengan Tomo Stocks")
    print("")
    
    pilihan = input("Pilih menu: ")
    
    print("")
    
    if pilihan == "1":
        kalkulator()
    elif pilihan == "2":
        notes()
    elif pilihan == "3":
        chatbot()
    elif pilihan == "4":
        print("Program selesai, sampai jumpa!")
        exit()
    else:
        print("")
        print("Menu tidak tersedia")
        print("")
        menu()
    return

#menu kalkulator
def kalkulator():
    print("Program kalkulator sederhana untuk menghitung deviden dari suatu saham!") 
    print("")
    
    # menu operasi
    print("Pilih Saham.")
    print("1.SIDO")
    print("2.ANTM")
    print("3.ITMG")
    print("4.BRIS")
    print("5.ICBP")
    
    print("")
    
    value =[12.5, 2.82, 307, 1.09714, 215]
    nama = ["SIDO", "ANTM", "ITMG", "BRIS", "ICBP"]
    def deviden(x, y):
        return x*y*100
     
    #meminta input user
    pilih = int(input("Deviden saham apa yang ingin kamu hitung (1/2/3/4/5)?  "))
    print("")
    
    lot = float(input("Jumlah lot saham pilihanmu = "))
        
    print("")
    
    def cetak():
        
        return
    
    def sido():
        n = 0
        print(nama[n],"\n Cumdate Tanggal 2 November 2020 \n", "Exdate Tanggal 3 November 2020")
        print("Kamu mendapat deviden sebesar Rp.", deviden(lot, value[n]), " dari saham ",nama[n], "berjumlah", lot, " lot.")
        cetak()
        return
    
    def antm():
        n = 1
        print(nama[n],"\n Cumdate Tanggal 19 Juni 2020 \n","Exdate Tanggal 22 Juni 2020")
        print("Kamu mendapat deviden sebesar Rp.", deviden(lot, value[n]), " dari saham ",nama[n], "berjumlah", lot, " lot.")
        cetak()
        return
 
    def itmg():
        n = 2
        print(nama[n],"\n Cumdate Tanggal 9 November 2020 \n","Exdate Tanggal 10 November 2020")
        print("Kamu mendapat deviden sebesar Rp.", deviden(lot, value[n]), " dari saham ",nama[n], "berjumlah", lot, " lot.")
        cetak()
        return
    
    def bris():
        n = 3
        print(nama[n],"\n Cumdate Tanggal 8 Mei 2020 \n","Exdate Tanggal 9 Mei 2020")
        print("Kamu mendapat deviden sebesar Rp.", deviden(lot, value[n]), " dari saham ",nama[n], "berjumlah", lot, " lot.")
        cetak()
        return
    
    def icbp():
        n = 4
        print(nama[n],"\n Cumdate Tanggal 23 Juli 2020 \n","Exdate Tanggal 24 Juli 2020")
        print("Kamu mendapat deviden sebesar Rp.", deviden(lot, value[n]), " dari saham ",nama[n], "berjumlah", lot, " lot.")
        cetak()
        return
    
    if pilih == 1:
        sido()     
    elif pilih == 2:
        antm()
    elif pilih == 3:
        itmg()
    elif pilih == 4:
        bris()
    elif pilih == 5:
        icbp()
    else:
        kalkulator()
    
     
    print("")
    print("")
    
    menu()
    return

#menu Buat Catatan
def notes():
    print("Buat catatan sederhana mengenai Money Management(MM) atau plan sahammu!") 
    print("")
    
    print("---Menu---")
    print("")
    print("1. Buat Catatan")
    print("2. Baca Catatan yang Ada")
    print("3. Kembali ke Menu Utama")
    print("")
    
    pilihan = int(input("Pilih menu (1/2): "))
    
    print("")
    
    #MENULIS CATATAN
    def catat():
        fwrite = open("CatatanSaham.txt", "a")
        n = print("")
        catat = str(input("Masukkan catatan: "))
        fwrite.write(catat + '\n')
        fwrite.close()
        print("---Catatan Selesai Dibuat---"+ '\n')
        notes()
    
    #MEMBACA CATATAN
    def baca():
        print("--Catatan kamu sekarang--")
        f = open("CatatanSaham.txt", "r")
        print(f.read())
        print("")
        print("-------------------------------------")
        notes()
    
    if pilihan == 1:
        catat()
    elif pilihan == 2:
        baca()
    elif pilihan == 3:
        menu()
    else:
        print("")
        print("Menu tidak tersedia")
        print("")
        notes()
    return

#PROGRAM CHATBOT

pernyataan = [
    [
        r"Halo|Hey|Hello|Hai",
        ["Hai",]
    ],
    [
        r"namamu|siapa namamu ?",
        ["Namaku Tomo Stocks dan aku adalah chatbot.",]
    ],
    [
        r"chatbot apa|Apa",
        ["Ini adalah bot. Apakah kamu sudah memulai investasi?",]
    ],
    [
        r"Sudah investasi|sudah",
        ["Bagus. Sudah berapa lama investasi?",]
    ],
    [
        r"maaf",
        ["Tidak apa-apa",]
    ],
    [
        r"kabarmu|bagaimana kabarmu",
        ["Aku baik. Bagimana kabarmu?",]
    ],
    [
        r"(.*)tahun|(.*)bulan",
        ["Bagus. Sudah tahu manfaat investasi?",]
    ],
    [
        r"belum",
        ["Ayo berinvestasi! Bukan hanya berkaitan dengan urusan kantong, melainkan manfaat itu berkaitan dengan banyak hal seperti psikologi dan mental. Cari tahu selengkapnya di https://koinworks.com/blog/manfaat-investasi-saham/",]
    ],
    [
        r"baik",
        ["Bagus. Apakah kamu sudah mulai berinvestasi?",]
    ]
]

def chatbot():
    print("Ngobrol dengan Tomo Stocks yuk! Adakah yang bisa saya bantu?")
    print("")
    chat = Chat(pernyataan, reflections)
    chat.converse()
    if __name__ == "__main__":
        print("")
        chatbot()
        chat.converse()
    else:
        menu()
menu()
